# %%
import numpy as np
from burgers_sin_exact import burgers_sin_show
from burgers_sin_exact import burgers_show_line
from burgers_sin_exact import burgers_show_animate

# %%
burgers_sin_show(
    xleft=0,
    xright=2 * np.pi,
    xnum=400,
    t=0.5,
    a=0,
    b=1,
    w=1,
    phi=0,
    ep=1e-6,
)
# Out:
# u0(x)=0+1*sin(1*x+0)
# tb = 1.0

# %%
burgers_sin_show(
    xleft=0,
    xright=2 * np.pi,
    xnum=400,
    t=1.3,
    a=0,
    b=1,
    w=1,
    phi=0,
    ep=1e-6,
)
# Out:
# u0(x)=0+1*sin(1*x+0)
# t(1.3) >= tb(1.0)
# Shock wave location: [3.14159265]

# %%
burgers_sin_show(
    xleft=-np.pi,
    xright= np.pi,
    xnum=400,
    t=0.4,
    a=1,
    b=2,
    w=1,
    phi=0,
    ep=1e-6,
)
# Out:
# u0(x)=1+2*sin(1*x+0)
# tb = 0.5

# %%
burgers_sin_show(
    xleft=-np.pi,
    xright=np.pi,
    xnum=400,
    t=1.0,
    a=1,
    b=2,
    w=1,
    phi=0,
    ep=1e-6,
)
# Out:
# u0(x)=1+2*sin(1*x+0)
# t(1.0) >= tb(0.5)
# Shock wave location: [-2.14159265]

# %%
burgers_sin_show(
    xleft=-2*np.pi,
    xright= 2*np.pi,
    xnum=400,
    t=5.0,
    a=1,
    b=2,
    w=1,
    phi=0,
    ep=1e-6,
)
# Out:
# u0(x)=1+2*sin(1*x+0)
# t(5.0) >= tb(0.5)
# Shock wave location: [-4.42477796  1.85840735]

# %%
burgers_sin_show(
    xleft=-1,
    xright=1,
    xnum=400,
    t=0.7,
    a=0.25,
    b=0.5,
    w=np.pi,
    phi=0,
    ep=1e-6,
)
# Out:
# u0(x)=0.25+0.5*sin(3.141592653589793*x+0)
# t(0.7) >= tb(0.6366197723675814)
# Shock wave location: [-0.825]

# %%
burgers_show_line(
    u0=lambda s: np.sin(s), xleft=0, xright=2*np.pi, num=100, tend=1.2
)

# %%
burgers_show_line(
    u0=lambda s: 1+2*np.sin(s), xleft=-2*np.pi, xright=2*np.pi, num=200, tend=1.0
)

# %%
def gaussian_distribution(x):
    mu = 0
    sigma = 0.6
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)


burgers_show_line(
    u0=gaussian_distribution, xleft=-np.pi, xright=np.pi, num=100, tend=2.0
)

# %%
def jump(x):
    result = np.ones_like(x)
    result[x < 0] = 1
    result[x > 1] = 0
    result[(x >= 0) & (x <= 1)] = 1 - x[(x >= 0) & (x <= 1)]

    return result


burgers_show_line(u0=jump, xleft=-2, xright=2, num=100, tend=1.0)

# %%
tmp = burgers_show_animate(
    u0=lambda s: np.sin(s), xleft=0, xright=2 * np.pi, num=100, tend=1.2
)
# tmp.save("demo1.gif")

# %%
def gaussian_distribution(x):
    mu = 0
    sigma = 0.6
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)


tmp = burgers_show_animate(
    u0=gaussian_distribution, xleft=-np.pi, xright=np.pi, num=200, tend=2.0
)
# tmp.save("demo2.gif")
# Out:
# d:\ProgramLang\miniconda3\Lib\site-packages\matplotlib\animation.py:872: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
def jump(x):
    result = np.ones_like(x)
    result[x < 0] = 1
    result[x > 1] = 0
    result[(x >= 0) & (x <= 1)] = 1 - x[(x >= 0) & (x <= 1)]

    return result

tmp = burgers_show_animate(
    u0=jump, xleft=-2, xright=2, num=100, tend=1.0
)
# tmp.save("demo3.gif")
